# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('./course_material/03/demos/m2_exploring_data/weather.csv')

# %% [markdown]
# ## Shape
#
# Tells us there are 8784 rows and 5 columns in the df.

# %%
df.shape
# Out:
# (8784, 5)

# %% [markdown]
# ## Info
#
# Gives us more info about what the object is, names, types, the type of Index and the amount of memory required.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MONTH     8784 non-null   int64
#  1   DAY       8784 non-null   int64
#  2   TIME      8784 non-null   int64
#  3   TEMP      8784 non-null   float64
#  4   PRESSURE  8784 non-null   int64
# dtypes: float64(1), int64(4)
# memory usage: 343.2 KB

# %% [markdown]
# ## Head / Tail
# Shows beginning and end rows, respectively, of dataframe. You can input an integer to give back that number of rows as the first arg.

# %%
df.head(50)
# Out:
#     MONTH  DAY  TIME  TEMP  PRESSURE
# 0       1    1     1   6.8     10207
# 1       1    1     2   5.8     10214
# 2       1    1     3   5.7     10220
# 3       1    1     4   6.0     10225
# 4       1    1     5   4.5     10230
# 5       1    1     6   2.0     10237
# 6       1    1     7   1.1     10242
# 7       1    1     8   0.7     10245
# 8       1    1     9   0.2     10248
# 9       1    1    10   2.0     10249
# 10      1    1    11   7.2     10245
# 11      1    1    12   7.9     10239
# 12      1    1    13   7.7     10231
# 13      1    1    14   7.2     10225
# 14      1    1    15   5.3     10220
# 15      1    1    16   5.0     10217
# 16      1    1    17   4.9     10205
# 17      1    1    18   4.9     10194
# 18      1    1    19   5.4     10188
# 19      1    1    20   5.7     10183
# 20      1    1    21   5.4     10170
# 21      1    1    22   5.3     10161
# 22      1    1    23   5.4     10146
# 23      1    1    24   5.6     10140
# ...

# %%
df.tail()
# Out:
#       MONTH  DAY  TIME  TEMP  PRESSURE
# 8779     12  366    20   3.5     10265
# 8780     12  366    21   3.4     10258
# 8781     12  366    22   3.0     10253
# 8782     12  366    23   2.8     10246
# 8783     12  366    24   2.8     10239

# %% [markdown]
# ## Describe
# Gives some statistical details about what information is available with our dataframae.

# %%
df.describe()
# Out:
#              MONTH          DAY         TIME         TEMP      PRESSURE
# count  8784.000000  8784.000000  8784.000000  8784.000000   8784.000000
# mean      6.513661   183.500000    12.500000    10.768613  10159.254781
# std       3.451430   105.660719     6.922581     6.420003    102.895130
# min       1.000000     1.000000     1.000000    -6.500000   9812.000000
# 25%       4.000000    92.000000     6.750000     6.100000  10102.000000
# 50%       7.000000   183.500000    12.500000    10.200000  10169.000000
# 75%      10.000000   275.000000    18.250000    15.900000  10227.000000
# max      12.000000   366.000000    24.000000    31.700000  10453.000000

# %%
df.mean()
# Out:
# MONTH           6.513661
# DAY           183.500000
# TIME           12.500000
# TEMP           10.768613
# PRESSURE    10159.254781
# dtype: float64

# %%
df.max()
# Out:
# MONTH          12.0
# DAY           366.0
# TIME           24.0
# TEMP           31.7
# PRESSURE    10453.0
# dtype: float64

# %%
df['PRESSURE'].min()
# Out:
# 9812

# %%
df['TEMP'].mode()
# Out:
# 0    6.4
# Name: TEMP, dtype: float64

# %%
df['TEMP'].plot()
# Out:
# <AxesSubplot:>

# %%
df['TEMP'].plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Stastistical Properties
#
# ### These work both on Series and DataFrames
# ### Maximum, Minimum, Mean, Median
# - `df.max(), df.min(), df.mean(), df.median()`
#
# ### counting values
# - `df.mode(), Series.value_counts()`
#
#  Distribution
# - `df.std(), df.var(), df.skew(), df.kurtosis(), df.quantile()`
